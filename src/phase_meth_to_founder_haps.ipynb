# %% [markdown]
# ### Setup

# %%
import importlib
import polars as pl

SAMPLE = '200081' 

pl.Config.set_tbl_rows(25)

from pathlib import Path

READ_PHASED_DIR = Path('/scratch/ucgd/lustre-labs/quinlan/data-shared/read-backed-phasing')
IHT_PHASED_DIR = Path('/scratch/ucgd/lustre-labs/quinlan/data-shared/haplotype-maps/CEPH1463.GRCh38')
METH_COUNT_READ_PHASED_DIR = Path(f'/scratch/ucgd/lustre-labs/quinlan/data-shared/dna-methylation/CEPH1463.GRCh38.hifi.count.read-backed-phased')
METH_MODEL_READ_PHASED_DIR = Path(f'/scratch/ucgd/lustre-labs/quinlan/data-shared/dna-methylation/CEPH1463.GRCh38.hifi.model.read-backed-phased')

import sys

REPO_DIR = Path('/scratch/ucgd/lustre-labs/quinlan/u6018199/tapestry')
sys.path.append(str(REPO_DIR / 'src/util')) # hover over, e.g., "from shell import shell", etc., below, and choose "quick fix" to make pylance aware of this path

# %%
VCF_READ_PHASED = f"{READ_PHASED_DIR}/{SAMPLE}.GRCh38.deepvariant.glnexus.phased.vcf.gz" # single-sample vcf from hiphase
TSV_READ_PHASE_BLOCKS = f"{READ_PHASED_DIR}/{SAMPLE}.GRCh38.hiphase.blocks.tsv" # single-sample tsv from hiphase
VCF_IHT_PHASED = f"{IHT_PHASED_DIR}/CEPH1463.GRCh38.pass.sorted.vcf.gz" # joint-called multi-sample vcf from gtg-ped-map/gtg-concordance
TXT_IHT_BLOCKS = f"{IHT_PHASED_DIR}/CEPH1463.GRCh38.iht.sorted.txt" # multi-sample iht blocks file from gtg-ped-map/gtg-concordance
# bed files from aligned_bam_to_cpg_scores:
BED_METH_COUNT_HAP1 = f"{METH_COUNT_READ_PHASED_DIR}/{SAMPLE}.GRCh38.haplotagged.hap1.bed.gz" 
BED_METH_COUNT_HAP2 = f"{METH_COUNT_READ_PHASED_DIR}/{SAMPLE}.GRCh38.haplotagged.hap2.bed.gz" 
BED_METH_MODEL_HAP1 = f"{METH_MODEL_READ_PHASED_DIR}/{SAMPLE}.GRCh38.haplotagged.hap1.bed.gz" 
BED_METH_MODEL_HAP2 = f"{METH_MODEL_READ_PHASED_DIR}/{SAMPLE}.GRCh38.haplotagged.hap2.bed.gz"

# %% [markdown]
# ### Phase alleles at SNPs to read-backed haplotypes and founder haplotypes

# %%
import get_all_phasing
importlib.reload(get_all_phasing)
from get_all_phasing import get_read_phasing

DF_READ_PHASING = get_read_phasing(VCF_READ_PHASED) 
DF_READ_PHASING
# Out:
# shape: (2_445_352, 8)
# ┌───────┬──────────┬──────────┬─────┬─────┬────────────────┬─────────────┬─────────────┐
# │ chrom ┆ start    ┆ end      ┆ REF ┆ ALT ┆ phase_block_id ┆ allele_hap1 ┆ allele_hap2 │
# │ ---   ┆ ---      ┆ ---      ┆ --- ┆ --- ┆ ---            ┆ ---         ┆ ---         │
# │ str   ┆ i64      ┆ i64      ┆ str ┆ str ┆ str            ┆ str         ┆ str         │
# ╞═══════╪══════════╪══════════╪═════╪═════╪════════════════╪═════════════╪═════════════╡
# │ chr1  ┆ 11862    ┆ 11863    ┆ C   ┆ A   ┆ 11863          ┆ 0           ┆ 1           │
# │ chr1  ┆ 11921    ┆ 11922    ┆ T   ┆ A   ┆ 11863          ┆ 0           ┆ 1           │
# │ chr1  ┆ 15117    ┆ 15118    ┆ A   ┆ G   ┆ 11863          ┆ 0           ┆ 1           │
# │ chr1  ┆ 15819    ┆ 15820    ┆ G   ┆ T   ┆ 11863          ┆ 1           ┆ 0           │
# │ chr1  ┆ 16013    ┆ 16014    ┆ C   ┆ T   ┆ 11863          ┆ 0           ┆ 1           │
# │ chr1  ┆ 16948    ┆ 16949    ┆ A   ┆ C   ┆ 11863          ┆ 0           ┆ 1           │
# │ chr1  ┆ 17019    ┆ 17020    ┆ G   ┆ A   ┆ 11863          ┆ 0           ┆ 1           │
# │ chr1  ┆ 17384    ┆ 17385    ┆ G   ┆ A   ┆ 11863          ┆ 0           ┆ 1           │
# │ chr1  ┆ 18088    ┆ 18089    ┆ G   ┆ T   ┆ 11863          ┆ 0           ┆ 1           │
# │ chr1  ┆ 19171    ┆ 19172    ┆ A   ┆ G   ┆ 11863          ┆ 0           ┆ 1           │
# │ chr1  ┆ 19240    ┆ 19241    ┆ C   ┆ T   ┆ 11863          ┆ 0           ┆ 1           │
# │ chr1  ┆ 19684    ┆ 19685    ┆ G   ┆ A   ┆ 11863          ┆ 0           ┆ 1           │
# │ chr1  ┆ 21023    ┆ 21024    ┆ C   ┆ T   ┆ 11863          ┆ 1           ┆ 0           │
# │ …     ┆ …        ┆ …        ┆ …   ┆ …   ┆ …              ┆ …           ┆ …           │
# │ chrY  ┆ 56879072 ┆ 56879073 ┆ G   ┆ A   ┆ 56821555       ┆ 1           ┆ 0           │
# │ chrY  ┆ 56879145 ┆ 56879146 ┆ C   ┆ A   ┆ 56821555       ┆ 0           ┆ 1           │
# │ chrY  ┆ 56879425 ┆ 56879426 ┆ G   ┆ T   ┆ 56821555       ┆ 1           ┆ 0           │
# │ chrY  ┆ 56879551 ┆ 56879552 ┆ C   ┆ G   ┆ 56821555       ┆ 1           ┆ 0           │
# │ chrY  ┆ 56880081 ┆ 56880082 ┆ G   ┆ T   ┆ 56821555       ┆ 0           ┆ 1           │
# │ chrY  ┆ 56880097 ┆ 56880098 ┆ A   ┆ C   ┆ 56821555       ┆ 0           ┆ 1           │
# │ chrY  ┆ 56880692 ┆ 56880693 ┆ T   ┆ G   ┆ 56821555       ┆ 0           ┆ 1           │
# │ chrY  ┆ 56881081 ┆ 56881082 ┆ G   ┆ A   ┆ 56821555       ┆ 0           ┆ 1           │
# │ chrY  ┆ 56883490 ┆ 56883491 ┆ G   ┆ A   ┆ 56821555       ┆ 0           ┆ 1           │
# │ chrY  ┆ 56883844 ┆ 56883845 ┆ C   ┆ G   ┆ 56821555       ┆ 0           ┆ 1           │
# │ chrY  ┆ 56884257 ┆ 56884258 ┆ G   ┆ T   ┆ 56821555       ┆ 0           ┆ 1           │
# │ chrY  ┆ 56887213 ┆ 56887214 ┆ G   ┆ A   ┆ 56821555       ┆ 0           ┆ 1           │
# └───────┴──────────┴──────────┴─────┴─────┴────────────────┴─────────────┴─────────────┘

# %%
import get_all_phasing
importlib.reload(get_all_phasing)
from get_all_phasing import get_read_phase_blocks

DF_READ_PHASE_BLOCKS = get_read_phase_blocks(TSV_READ_PHASE_BLOCKS)
DF_READ_PHASE_BLOCKS
# Out:
# shape: (10_017, 7)
# ┌────────────────┬─────────────┬────────────────┬───────────────┬─────────┬─────────┬──────────────┐
# │ source_block_i ┆ sample_name ┆ phase_block_id ┆ chrom         ┆ start   ┆ end     ┆ num_variants │
# │ ndex           ┆ ---         ┆ ---            ┆ ---           ┆ ---     ┆ ---     ┆ ---          │
# │ ---            ┆ i64         ┆ str            ┆ str           ┆ i64     ┆ i64     ┆ i64          │
# │ i64            ┆             ┆                ┆               ┆         ┆         ┆              │
# ╞════════════════╪═════════════╪════════════════╪═══════════════╪═════════╪═════════╪══════════════╡
# │ 0              ┆ 200081      ┆ 11863          ┆ chr1          ┆ 11863   ┆ 204487  ┆ 479          │
# │ 1              ┆ 200081      ┆ 257716         ┆ chr1          ┆ 257716  ┆ 292262  ┆ 110          │
# │ 2              ┆ 200081      ┆ 350805         ┆ chr1          ┆ 350805  ┆ 396627  ┆ 205          │
# │ 4              ┆ 200081      ┆ 416412         ┆ chr1          ┆ 416412  ┆ 433777  ┆ 76           │
# │ 6              ┆ 200081      ┆ 492339         ┆ chr1          ┆ 492339  ┆ 532812  ┆ 56           │
# │ 8              ┆ 200081      ┆ 593123         ┆ chr1          ┆ 593123  ┆ 1314109 ┆ 1169         │
# │ 9              ┆ 200081      ┆ 1351126        ┆ chr1          ┆ 1351126 ┆ 1382658 ┆ 5            │
# │ 10             ┆ 200081      ┆ 1421668        ┆ chr1          ┆ 1421668 ┆ 1427528 ┆ 2            │
# │ 11             ┆ 200081      ┆ 1432961        ┆ chr1          ┆ 1432961 ┆ 2931691 ┆ 2168         │
# │ 12             ┆ 200081      ┆ 2961801        ┆ chr1          ┆ 2961801 ┆ 4207029 ┆ 2441         │
# │ 13             ┆ 200081      ┆ 4229875        ┆ chr1          ┆ 4229875 ┆ 4783469 ┆ 1046         │
# │ 15             ┆ 200081      ┆ 4898018        ┆ chr1          ┆ 4898018 ┆ 6324750 ┆ 1649         │
# │ 16             ┆ 200081      ┆ 6355551        ┆ chr1          ┆ 6355551 ┆ 6397259 ┆ 3            │
# │ …              ┆ …           ┆ …              ┆ …             ┆ …       ┆ …       ┆ …            │
# │ 11448          ┆ 200081      ┆ 13433          ┆ chrUn_KI27058 ┆ 13433   ┆ 13433   ┆ 1            │
# │                ┆             ┆                ┆ 9v1           ┆         ┆         ┆              │
# │ 11494          ┆ 200081      ┆ 4607           ┆ chrUn_GL00019 ┆ 4607    ┆ 20682   ┆ 2            │
# │                ┆             ┆                ┆ 5v1           ┆         ┆         ┆              │
# │ 11495          ┆ 200081      ┆ 55076          ┆ chrUn_GL00019 ┆ 55076   ┆ 101142  ┆ 4            │
# │                ┆             ┆                ┆ 5v1           ┆         ┆         ┆              │
# │ 11496          ┆ 200081      ┆ 143700         ┆ chrUn_GL00019 ┆ 143700  ┆ 168955  ┆ 2            │
# │                ┆             ┆                ┆ 5v1           ┆         ┆         ┆              │
# │ 11497          ┆ 200081      ┆ 21866          ┆ chrUn_GL00021 ┆ 21866   ┆ 64325   ┆ 3            │
# │                ┆             ┆                ┆ 9v1           ┆         ┆         ┆              │
# │ 11499          ┆ 200081      ┆ 136326         ┆ chrUn_GL00021 ┆ 136326  ┆ 139793  ┆ 2            │
# │                ┆             ┆                ┆ 9v1           ┆         ┆         ┆              │
# │ 11500          ┆ 200081      ┆ 166482         ┆ chrUn_GL00021 ┆ 166482  ┆ 166903  ┆ 2            │
# │                ┆             ┆                ┆ 9v1           ┆         ┆         ┆              │
# │ 11501          ┆ 200081      ┆ 13059          ┆ chrUn_GL00022 ┆ 13059   ┆ 13059   ┆ 2            │
# │                ┆             ┆                ┆ 0v1           ┆         ┆         ┆              │
# │ 11503          ┆ 200081      ┆ 119429         ┆ chrUn_GL00022 ┆ 119429  ┆ 148951  ┆ 6            │
# │                ┆             ┆                ┆ 0v1           ┆         ┆         ┆              │
# │ 11504          ┆ 200081      ┆ 5544           ┆ chrUn_GL00022 ┆ 5544    ┆ 56793   ┆ 5            │
# │                ┆             ┆                ┆ 4v1           ┆         ┆         ┆              │
# │ 11506          ┆ 200081      ┆ 125072         ┆ chrUn_GL00022 ┆ 125072  ┆ 174800  ┆ 4            │
# │                ┆             ┆                ┆ 4v1           ┆         ┆         ┆              │
# │ 11507          ┆ 200081      ┆ 117273         ┆ chrUn_KI27074 ┆ 117273  ┆ 118449  ┆ 2            │
# │                ┆             ┆                ┆ 1v1           ┆         ┆         ┆              │
# └────────────────┴─────────────┴────────────────┴───────────────┴─────────┴─────────┴──────────────┘

# %%
import get_all_phasing
importlib.reload(get_all_phasing)
from get_all_phasing import get_iht_phasing

DF_IHT_PHASING = get_iht_phasing(SAMPLE, VCF_IHT_PHASED)
DF_IHT_PHASING
# Out:
# shape: (2_192_365, 7)
# ┌───────┬───────────┬───────────┬─────┬─────┬────────────┬────────────┐
# │ chrom ┆ start     ┆ end       ┆ REF ┆ ALT ┆ allele_pat ┆ allele_mat │
# │ ---   ┆ ---       ┆ ---       ┆ --- ┆ --- ┆ ---        ┆ ---        │
# │ str   ┆ i64       ┆ i64       ┆ str ┆ str ┆ str        ┆ str        │
# ╞═══════╪═══════════╪═══════════╪═════╪═════╪════════════╪════════════╡
# │ chr1  ┆ 497702    ┆ 497703    ┆ T   ┆ C   ┆ 1          ┆ 0          │
# │ chr1  ┆ 500803    ┆ 500804    ┆ T   ┆ C   ┆ 1          ┆ 0          │
# │ chr1  ┆ 502903    ┆ 502904    ┆ T   ┆ C   ┆ 1          ┆ 0          │
# │ chr1  ┆ 504316    ┆ 504317    ┆ T   ┆ C   ┆ 0          ┆ 1          │
# │ chr1  ┆ 505781    ┆ 505782    ┆ C   ┆ T   ┆ 0          ┆ 1          │
# │ chr1  ┆ 506629    ┆ 506630    ┆ A   ┆ G   ┆ 1          ┆ 0          │
# │ chr1  ┆ 512114    ┆ 512115    ┆ A   ┆ G   ┆ 0          ┆ 1          │
# │ chr1  ┆ 514052    ┆ 514053    ┆ A   ┆ G   ┆ 1          ┆ 0          │
# │ chr1  ┆ 515920    ┆ 515921    ┆ C   ┆ T   ┆ 1          ┆ 0          │
# │ chr1  ┆ 516229    ┆ 516230    ┆ T   ┆ C   ┆ 0          ┆ 1          │
# │ chr1  ┆ 516337    ┆ 516338    ┆ C   ┆ A   ┆ 0          ┆ 1          │
# │ chr1  ┆ 516597    ┆ 516598    ┆ T   ┆ A   ┆ 0          ┆ 1          │
# │ chr1  ┆ 517580    ┆ 517581    ┆ A   ┆ T   ┆ 0          ┆ 1          │
# │ …     ┆ …         ┆ …         ┆ …   ┆ …   ┆ …          ┆ …          │
# │ chrX  ┆ 155175208 ┆ 155175209 ┆ A   ┆ G   ┆ 1          ┆ 0          │
# │ chrX  ┆ 155292579 ┆ 155292580 ┆ C   ┆ A   ┆ 0          ┆ 1          │
# │ chrX  ┆ 155417018 ┆ 155417019 ┆ G   ┆ A   ┆ 0          ┆ 1          │
# │ chrX  ┆ 155443919 ┆ 155443920 ┆ A   ┆ G   ┆ 0          ┆ 1          │
# │ chrX  ┆ 155522298 ┆ 155522299 ┆ A   ┆ G   ┆ 0          ┆ 1          │
# │ chrX  ┆ 155525685 ┆ 155525686 ┆ C   ┆ A   ┆ 0          ┆ 1          │
# │ chrX  ┆ 155534932 ┆ 155534933 ┆ C   ┆ T   ┆ 1          ┆ 0          │
# │ chrX  ┆ 155543102 ┆ 155543103 ┆ G   ┆ A   ┆ 1          ┆ 0          │
# │ chrX  ┆ 155558975 ┆ 155558976 ┆ G   ┆ A   ┆ 0          ┆ 1          │
# │ chrX  ┆ 155560160 ┆ 155560161 ┆ C   ┆ T   ┆ 0          ┆ 1          │
# │ chrX  ┆ 155560196 ┆ 155560197 ┆ T   ┆ C   ┆ 0          ┆ 1          │
# │ chrX  ┆ 155652099 ┆ 155652100 ┆ A   ┆ C   ┆ 0          ┆ 1          │
# └───────┴───────────┴───────────┴─────┴─────┴────────────┴────────────┘

# %%
import get_all_phasing
importlib.reload(get_all_phasing)
from get_all_phasing import get_iht_blocks

DF_IHT_BLOCKS = get_iht_blocks(SAMPLE, TXT_IHT_BLOCKS)
DF_IHT_BLOCKS
# Out:
# shape: (1_329, 5)
# ┌───────┬───────────┬───────────┬───────────────────┬───────────────────┐
# │ chrom ┆ start     ┆ end       ┆ founder_label_pat ┆ founder_label_mat │
# │ ---   ┆ ---       ┆ ---       ┆ ---               ┆ ---               │
# │ str   ┆ i64       ┆ i64       ┆ str               ┆ str               │
# ╞═══════╪═══════════╪═══════════╪═══════════════════╪═══════════════════╡
# │ chr1  ┆ 13301     ┆ 1610923   ┆ B                 ┆ I                 │
# │ chr1  ┆ 1613420   ┆ 3184712   ┆ B                 ┆ I                 │
# │ chr1  ┆ 3184788   ┆ 3200879   ┆ B                 ┆ I                 │
# │ chr1  ┆ 3203589   ┆ 3398794   ┆ B                 ┆ I                 │
# │ chr1  ┆ 3399126   ┆ 5038259   ┆ B                 ┆ I                 │
# │ chr1  ┆ 5038659   ┆ 5097605   ┆ B                 ┆ I                 │
# │ chr1  ┆ 5097819   ┆ 6082247   ┆ B                 ┆ I                 │
# │ chr1  ┆ 6082326   ┆ 9098705   ┆ B                 ┆ I                 │
# │ chr1  ┆ 9098937   ┆ 9424618   ┆ B                 ┆ I                 │
# │ chr1  ┆ 9424760   ┆ 10778498  ┆ B                 ┆ I                 │
# │ chr1  ┆ 10780847  ┆ 10842395  ┆ B                 ┆ I                 │
# │ chr1  ┆ 10844342  ┆ 11698580  ┆ B                 ┆ I                 │
# │ chr1  ┆ 11700970  ┆ 14370247  ┆ B                 ┆ K                 │
# │ …     ┆ …         ┆ …         ┆ …                 ┆ …                 │
# │ chrX  ┆ 50144870  ┆ 69322531  ┆ A                 ┆ K                 │
# │ chrX  ┆ 69324742  ┆ 87721050  ┆ A                 ┆ K                 │
# │ chrX  ┆ 87821991  ┆ 100501528 ┆ A                 ┆ K                 │
# │ chrX  ┆ 100508605 ┆ 116027208 ┆ A                 ┆ K                 │
# │ chrX  ┆ 116121813 ┆ 116489196 ┆ A                 ┆ K                 │
# │ chrX  ┆ 116494939 ┆ 124541644 ┆ A                 ┆ K                 │
# │ chrX  ┆ 124543908 ┆ 125567640 ┆ A                 ┆ K                 │
# │ chrX  ┆ 125567954 ┆ 151184516 ┆ A                 ┆ K                 │
# │ chrX  ┆ 151193172 ┆ 151984204 ┆ A                 ┆ K                 │
# │ chrX  ┆ 151986447 ┆ 153723442 ┆ A                 ┆ K                 │
# │ chrX  ┆ 153754792 ┆ 155700568 ┆ A                 ┆ K                 │
# │ chrY  ┆ 3842441   ┆ 56887843  ┆ A                 ┆ ?                 │
# └───────┴───────────┴───────────┴───────────────────┴───────────────────┘

# %%
import get_all_phasing
importlib.reload(get_all_phasing)
from get_all_phasing import get_all_phasing

# Note: there are no bit vectors prior to 500kb: 
# https://quinlangroup.slack.com/archives/C09027S4C5Q/p1750792033498849
DF_ALL_PHASING = get_all_phasing(
    DF_READ_PHASING, 
    DF_READ_PHASE_BLOCKS, 
    DF_IHT_PHASING, 
    DF_IHT_BLOCKS
)
DF_ALL_PHASING
# Out:
# shape: (2_189_885, 15)
# ┌───────┬───────────┬───────────┬─────┬───┬──────────────┬─────────────┬─────────────┬─────────────┐
# │ chrom ┆ start     ┆ end       ┆ REF ┆ … ┆ start_iht_bl ┆ end_iht_blo ┆ founder_lab ┆ founder_lab │
# │ ---   ┆ ---       ┆ ---       ┆ --- ┆   ┆ ock          ┆ ck          ┆ el_pat_iht_ ┆ el_mat_iht_ │
# │ str   ┆ i64       ┆ i64       ┆ str ┆   ┆ ---          ┆ ---         ┆ block       ┆ block       │
# │       ┆           ┆           ┆     ┆   ┆ i64          ┆ i64         ┆ ---         ┆ ---         │
# │       ┆           ┆           ┆     ┆   ┆              ┆             ┆ str         ┆ str         │
# ╞═══════╪═══════════╪═══════════╪═════╪═══╪══════════════╪═════════════╪═════════════╪═════════════╡
# │ chr1  ┆ 497702    ┆ 497703    ┆ T   ┆ … ┆ 13301        ┆ 1610923     ┆ B           ┆ I           │
# │ chr1  ┆ 500803    ┆ 500804    ┆ T   ┆ … ┆ 13301        ┆ 1610923     ┆ B           ┆ I           │
# │ chr1  ┆ 502903    ┆ 502904    ┆ T   ┆ … ┆ 13301        ┆ 1610923     ┆ B           ┆ I           │
# │ chr1  ┆ 504316    ┆ 504317    ┆ T   ┆ … ┆ 13301        ┆ 1610923     ┆ B           ┆ I           │
# │ chr1  ┆ 505781    ┆ 505782    ┆ C   ┆ … ┆ 13301        ┆ 1610923     ┆ B           ┆ I           │
# │ chr1  ┆ 506629    ┆ 506630    ┆ A   ┆ … ┆ 13301        ┆ 1610923     ┆ B           ┆ I           │
# │ chr1  ┆ 512114    ┆ 512115    ┆ A   ┆ … ┆ 13301        ┆ 1610923     ┆ B           ┆ I           │
# │ chr1  ┆ 514052    ┆ 514053    ┆ A   ┆ … ┆ 13301        ┆ 1610923     ┆ B           ┆ I           │
# │ chr1  ┆ 515920    ┆ 515921    ┆ C   ┆ … ┆ 13301        ┆ 1610923     ┆ B           ┆ I           │
# │ chr1  ┆ 516229    ┆ 516230    ┆ T   ┆ … ┆ 13301        ┆ 1610923     ┆ B           ┆ I           │
# │ chr1  ┆ 516337    ┆ 516338    ┆ C   ┆ … ┆ 13301        ┆ 1610923     ┆ B           ┆ I           │
# │ chr1  ┆ 516597    ┆ 516598    ┆ T   ┆ … ┆ 13301        ┆ 1610923     ┆ B           ┆ I           │
# │ chr1  ┆ 517580    ┆ 517581    ┆ A   ┆ … ┆ 13301        ┆ 1610923     ┆ B           ┆ I           │
# │ …     ┆ …         ┆ …         ┆ …   ┆ … ┆ …            ┆ …           ┆ …           ┆ …           │
# │ chrX  ┆ 154993497 ┆ 154993498 ┆ C   ┆ … ┆ 153754792    ┆ 155700568   ┆ A           ┆ K           │
# │ chrX  ┆ 155292579 ┆ 155292580 ┆ C   ┆ … ┆ 153754792    ┆ 155700568   ┆ A           ┆ K           │
# │ chrX  ┆ 155417018 ┆ 155417019 ┆ G   ┆ … ┆ 153754792    ┆ 155700568   ┆ A           ┆ K           │
# │ chrX  ┆ 155443919 ┆ 155443920 ┆ A   ┆ … ┆ 153754792    ┆ 155700568   ┆ A           ┆ K           │
# │ chrX  ┆ 155522298 ┆ 155522299 ┆ A   ┆ … ┆ 153754792    ┆ 155700568   ┆ A           ┆ K           │
# │ chrX  ┆ 155525685 ┆ 155525686 ┆ C   ┆ … ┆ 153754792    ┆ 155700568   ┆ A           ┆ K           │
# │ chrX  ┆ 155534932 ┆ 155534933 ┆ C   ┆ … ┆ 153754792    ┆ 155700568   ┆ A           ┆ K           │
# │ chrX  ┆ 155543102 ┆ 155543103 ┆ G   ┆ … ┆ 153754792    ┆ 155700568   ┆ A           ┆ K           │
# │ chrX  ┆ 155558975 ┆ 155558976 ┆ G   ┆ … ┆ 153754792    ┆ 155700568   ┆ A           ┆ K           │
# │ chrX  ┆ 155560160 ┆ 155560161 ┆ C   ┆ … ┆ 153754792    ┆ 155700568   ┆ A           ┆ K           │
# │ chrX  ┆ 155560196 ┆ 155560197 ┆ T   ┆ … ┆ 153754792    ┆ 155700568   ┆ A           ┆ K           │
# │ chrX  ┆ 155652099 ┆ 155652100 ┆ A   ┆ … ┆ 153754792    ┆ 155700568   ┆ A           ┆ K           │
# └───────┴───────────┴───────────┴─────┴───┴──────────────┴─────────────┴─────────────┴─────────────┘

# %%
# import bioframe as bf

# pl.DataFrame(bf.select(
#     df=DF_ALL_PHASING.to_pandas(), 
#     region="chr1:500,000-1,500,000",
#     cols=["chrom", "start", "end"]
# ))

# %% [markdown]
# ### Construct a Hap Map, consisting of intervals in which read-backed haplotypes are mapped to founder haplotypes

# %%
import get_hap_map
importlib.reload(get_hap_map)
from get_hap_map import get_hap_map

DF_HAP_MAP, DF_SITES, DF_SITES_MISMATCH = get_hap_map(DF_ALL_PHASING)
DF_HAP_MAP
# Out:
# shape: (8_904, 7)
# ┌───────┬───────────┬───────────┬─────────────────┬────────────────┬────────────────┬──────────────┐
# │ chrom ┆ start     ┆ end       ┆ paternal_haplot ┆ maternal_haplo ┆ haplotype_conc ┆ num_het_SNVs │
# │ ---   ┆ ---       ┆ ---       ┆ ype             ┆ type           ┆ ordance        ┆ ---          │
# │ str   ┆ i64       ┆ i64       ┆ ---             ┆ ---            ┆ ---            ┆ i64          │
# │       ┆           ┆           ┆ str             ┆ str            ┆ f64            ┆              │
# ╞═══════╪═══════════╪═══════════╪═════════════════╪════════════════╪════════════════╪══════════════╡
# │ chr1  ┆ 492339    ┆ 532812    ┆ B_hap2          ┆ I_hap1         ┆ 1.0            ┆ 16           │
# │ chr1  ┆ 593123    ┆ 1314109   ┆ B_hap2          ┆ I_hap1         ┆ 0.993119       ┆ 436          │
# │ chr1  ┆ 1351126   ┆ 1382658   ┆ B_hap2          ┆ I_hap1         ┆ 1.0            ┆ 1            │
# │ chr1  ┆ 1421668   ┆ 1427528   ┆ B_hap1          ┆ I_hap2         ┆ 1.0            ┆ 1            │
# │ chr1  ┆ 1432961   ┆ 1610923   ┆ B_hap1          ┆ I_hap2         ┆ 1.0            ┆ 28           │
# │ chr1  ┆ 1613420   ┆ 2931691   ┆ B_hap1          ┆ I_hap2         ┆ 1.0            ┆ 1201         │
# │ chr1  ┆ 2961801   ┆ 3184712   ┆ B_hap2          ┆ I_hap1         ┆ 1.0            ┆ 392          │
# │ chr1  ┆ 3184788   ┆ 3200879   ┆ B_hap2          ┆ I_hap1         ┆ 1.0            ┆ 1            │
# │ chr1  ┆ 3203589   ┆ 3398794   ┆ B_hap2          ┆ I_hap1         ┆ 1.0            ┆ 243          │
# │ chr1  ┆ 3399126   ┆ 4207029   ┆ B_hap2          ┆ I_hap1         ┆ 1.0            ┆ 1114         │
# │ chr1  ┆ 4229875   ┆ 4783469   ┆ B_hap2          ┆ I_hap1         ┆ 1.0            ┆ 818          │
# │ chr1  ┆ 4898018   ┆ 5038259   ┆ B_hap1          ┆ I_hap2         ┆ 1.0            ┆ 231          │
# │ chr1  ┆ 5038659   ┆ 5097605   ┆ B_hap1          ┆ I_hap2         ┆ 1.0            ┆ 58           │
# │ …     ┆ …         ┆ …         ┆ …               ┆ …              ┆ …              ┆ …            │
# │ chrX  ┆ 154273233 ┆ 154345132 ┆ A_hap2          ┆ K_hap1         ┆ 1.0            ┆ 4            │
# │ chrX  ┆ 154382344 ┆ 154408335 ┆ A_hap2          ┆ K_hap1         ┆ 1.0            ┆ 2            │
# │ chrX  ┆ 154436815 ┆ 154436815 ┆ A_hap1          ┆ K_hap2         ┆ 1.0            ┆ 1            │
# │ chrX  ┆ 154455718 ┆ 154540377 ┆ A_hap1          ┆ K_hap2         ┆ 1.0            ┆ 6            │
# │ chrX  ┆ 154565360 ┆ 154672314 ┆ A_hap2          ┆ K_hap1         ┆ 1.0            ┆ 4            │
# │ chrX  ┆ 154787101 ┆ 154856621 ┆ A_hap1          ┆ K_hap2         ┆ 1.0            ┆ 3            │
# │ chrX  ┆ 154875736 ┆ 154902733 ┆ A_hap1          ┆ K_hap2         ┆ 1.0            ┆ 2            │
# │ chrX  ┆ 154941725 ┆ 154993498 ┆ A_hap2          ┆ K_hap1         ┆ 1.0            ┆ 3            │
# │ chrX  ┆ 155280990 ┆ 155292580 ┆ A_hap2          ┆ K_hap1         ┆ 1.0            ┆ 1            │
# │ chrX  ┆ 155370893 ┆ 155485214 ┆ A_hap2          ┆ K_hap1         ┆ 1.0            ┆ 2            │
# │ chrX  ┆ 155516010 ┆ 155585416 ┆ A_hap2          ┆ K_hap1         ┆ 1.0            ┆ 7            │
# │ chrX  ┆ 155616130 ┆ 155659104 ┆ A_hap2          ┆ K_hap1         ┆ 1.0            ┆ 1            │
# └───────┴───────────┴───────────┴─────────────────┴────────────────┴────────────────┴──────────────┘

# %%
DF_HAP_MAP.filter(pl.col("haplotype_concordance") < 1.0)
# Out:
# shape: (509, 7)
# ┌───────┬───────────┬───────────┬─────────────────┬────────────────┬────────────────┬──────────────┐
# │ chrom ┆ start     ┆ end       ┆ paternal_haplot ┆ maternal_haplo ┆ haplotype_conc ┆ num_het_SNVs │
# │ ---   ┆ ---       ┆ ---       ┆ ype             ┆ type           ┆ ordance        ┆ ---          │
# │ str   ┆ i64       ┆ i64       ┆ ---             ┆ ---            ┆ ---            ┆ i64          │
# │       ┆           ┆           ┆ str             ┆ str            ┆ f64            ┆              │
# ╞═══════╪═══════════╪═══════════╪═════════════════╪════════════════╪════════════════╪══════════════╡
# │ chr1  ┆ 593123    ┆ 1314109   ┆ B_hap2          ┆ I_hap1         ┆ 0.993119       ┆ 436          │
# │ chr1  ┆ 8329093   ┆ 9098705   ┆ B_hap1          ┆ I_hap2         ┆ 0.718696       ┆ 583          │
# │ chr1  ┆ 13009397  ┆ 13267330  ┆ B_hap1          ┆ K_hap2         ┆ 0.714286       ┆ 7            │
# │ chr1  ┆ 14551881  ┆ 14943007  ┆ B_hap2          ┆ K_hap1         ┆ 0.514658       ┆ 307          │
# │ chr1  ┆ 18434710  ┆ 19541226  ┆ B_hap1          ┆ K_hap2         ┆ 0.952234       ┆ 1298         │
# │ chr1  ┆ 25776419  ┆ 26154619  ┆ B_hap2          ┆ K_hap1         ┆ 0.960265       ┆ 151          │
# │ chr1  ┆ 27783490  ┆ 28585938  ┆ B_hap2          ┆ K_hap1         ┆ 0.996099       ┆ 769          │
# │ chr1  ┆ 31384925  ┆ 31840697  ┆ B_hap2          ┆ K_hap1         ┆ 0.98806        ┆ 335          │
# │ chr1  ┆ 35192783  ┆ 35589188  ┆ B_hap2          ┆ K_hap1         ┆ 0.705882       ┆ 17           │
# │ chr1  ┆ 35938634  ┆ 36039515  ┆ B_hap1          ┆ K_hap2         ┆ 0.571429       ┆ 7            │
# │ chr1  ┆ 36083895  ┆ 36450853  ┆ B_hap1          ┆ K_hap2         ┆ 0.964497       ┆ 169          │
# │ chr1  ┆ 42097575  ┆ 42729449  ┆ B_hap2          ┆ K_hap1         ┆ 0.976898       ┆ 303          │
# │ chr1  ┆ 52044130  ┆ 52195856  ┆ B_hap2          ┆ I_hap1         ┆ 0.615385       ┆ 13           │
# │ …     ┆ …         ┆ …         ┆ …               ┆ …              ┆ …              ┆ …            │
# │ chrX  ┆ 84682046  ┆ 84738996  ┆ A_hap2          ┆ K_hap1         ┆ 0.666667       ┆ 3            │
# │ chrX  ┆ 90546108  ┆ 90635255  ┆ A_hap2          ┆ K_hap1         ┆ 0.75           ┆ 4            │
# │ chrX  ┆ 103856744 ┆ 104071390 ┆ A_hap2          ┆ K_hap1         ┆ 0.577465       ┆ 71           │
# │ chrX  ┆ 107549820 ┆ 107899182 ┆ A_hap1          ┆ K_hap2         ┆ 0.608696       ┆ 23           │
# │ chrX  ┆ 111318190 ┆ 111470098 ┆ A_hap2          ┆ K_hap1         ┆ 0.666667       ┆ 9            │
# │ chrX  ┆ 119829124 ┆ 119970960 ┆ A_hap2          ┆ K_hap1         ┆ 0.970149       ┆ 67           │
# │ chrX  ┆ 128399047 ┆ 129006548 ┆ A_hap1          ┆ K_hap2         ┆ 0.694301       ┆ 193          │
# │ chrX  ┆ 129600841 ┆ 129789109 ┆ A_hap2          ┆ K_hap1         ┆ 0.987952       ┆ 83           │
# │ chrX  ┆ 137603842 ┆ 138498822 ┆ A_hap2          ┆ K_hap1         ┆ 0.99802        ┆ 505          │
# │ chrX  ┆ 140354115 ┆ 141322788 ┆ A_hap2          ┆ K_hap1         ┆ 0.565517       ┆ 580          │
# │ chrX  ┆ 141545447 ┆ 141874586 ┆ A_hap1          ┆ K_hap2         ┆ 0.971154       ┆ 208          │
# │ chrX  ┆ 150081234 ┆ 150128778 ┆ A_hap2          ┆ K_hap1         ┆ 0.6            ┆ 5            │
# └───────┴───────────┴───────────┴─────────────────┴────────────────┴────────────────┴──────────────┘

# %%
DF_SITES_MISMATCH
# Out:
# shape: (33_390, 5)
# ┌───────┬───────────┬───────────┬─────┬─────┐
# │ chrom ┆ start     ┆ end       ┆ REF ┆ ALT │
# │ ---   ┆ ---       ┆ ---       ┆ --- ┆ --- │
# │ str   ┆ i64       ┆ i64       ┆ str ┆ str │
# ╞═══════╪═══════════╪═══════════╪═════╪═════╡
# │ chr5  ┆ 28950     ┆ 28951     ┆ T   ┆ G   │
# │ chr5  ┆ 29524     ┆ 29525     ┆ C   ┆ T   │
# │ chr5  ┆ 31108     ┆ 31109     ┆ G   ┆ A   │
# │ chr5  ┆ 32887     ┆ 32888     ┆ G   ┆ A   │
# │ chr5  ┆ 33800     ┆ 33801     ┆ A   ┆ T   │
# │ chr5  ┆ 34868     ┆ 34869     ┆ A   ┆ G   │
# │ chr5  ┆ 34959     ┆ 34960     ┆ C   ┆ T   │
# │ chr5  ┆ 34960     ┆ 34961     ┆ G   ┆ A   │
# │ chr5  ┆ 35001     ┆ 35002     ┆ C   ┆ T   │
# │ chr5  ┆ 36345     ┆ 36346     ┆ T   ┆ C   │
# │ chr5  ┆ 36645     ┆ 36646     ┆ A   ┆ G   │
# │ chr5  ┆ 36655     ┆ 36656     ┆ A   ┆ G   │
# │ chr5  ┆ 36739     ┆ 36740     ┆ G   ┆ A   │
# │ …     ┆ …         ┆ …         ┆ …   ┆ …   │
# │ chr1  ┆ 245686792 ┆ 245686793 ┆ C   ┆ T   │
# │ chr1  ┆ 245698268 ┆ 245698269 ┆ C   ┆ T   │
# │ chr1  ┆ 246275755 ┆ 246275756 ┆ T   ┆ A   │
# │ chr1  ┆ 248030751 ┆ 248030752 ┆ A   ┆ T   │
# │ chr1  ┆ 248044528 ┆ 248044529 ┆ C   ┆ T   │
# │ chr1  ┆ 248063977 ┆ 248063978 ┆ A   ┆ G   │
# │ chr1  ┆ 248068768 ┆ 248068769 ┆ T   ┆ A   │
# │ chr1  ┆ 248078208 ┆ 248078209 ┆ G   ┆ A   │
# │ chr1  ┆ 248099341 ┆ 248099342 ┆ A   ┆ G   │
# │ chr1  ┆ 248100715 ┆ 248100716 ┆ C   ┆ T   │
# │ chr1  ┆ 248108181 ┆ 248108182 ┆ G   ┆ C   │
# │ chr1  ┆ 248117218 ┆ 248117219 ┆ G   ┆ A   │
# └───────┴───────────┴───────────┴─────┴─────┘

# %% [markdown]
# ### Get HiFi DNA methylation levels (both count-based and model-based) at CpG sites phased to hap1/hap2

# %%
import get_meth_hap1_hap2
importlib.reload(get_meth_hap1_hap2)
from get_meth_hap1_hap2 import get_meth_hap1_hap2

DF_METH_COUNT_HAP1_HAP2 = get_meth_hap1_hap2(
    pb_cpg_tool_mode='count', 
    bed_hap1=BED_METH_COUNT_HAP1, 
    bed_hap2=BED_METH_COUNT_HAP2
)
DF_METH_MODEL_HAP1_HAP2 = get_meth_hap1_hap2(
    pb_cpg_tool_mode='model', 
    bed_hap1=BED_METH_MODEL_HAP1, 
    bed_hap2=BED_METH_MODEL_HAP2
)

# %%
DF_METH_COUNT_HAP1_HAP2
# Out:
# shape: (26_729_958, 7)
# ┌───────┬──────────┬──────────┬─────────────────┬────────────────┬────────────────┬────────────────┐
# │ chrom ┆ start    ┆ end      ┆ total_read_coun ┆ methylation_le ┆ total_read_cou ┆ methylation_le │
# │ ---   ┆ ---      ┆ ---      ┆ t_hap1          ┆ vel_hap1       ┆ nt_hap2        ┆ vel_hap2       │
# │ str   ┆ i64      ┆ i64      ┆ ---             ┆ ---            ┆ ---            ┆ ---            │
# │       ┆          ┆          ┆ i64             ┆ f64            ┆ i64            ┆ f64            │
# ╞═══════╪══════════╪══════════╪═════════════════╪════════════════╪════════════════╪════════════════╡
# │ chr1  ┆ 14061    ┆ 14062    ┆ null            ┆ null           ┆ 10             ┆ 0.4            │
# │ chr1  ┆ 14178    ┆ 14179    ┆ null            ┆ null           ┆ 10             ┆ 0.6            │
# │ chr1  ┆ 14348    ┆ 14349    ┆ null            ┆ null           ┆ 11             ┆ 0.727          │
# │ chr1  ┆ 14353    ┆ 14354    ┆ null            ┆ null           ┆ 11             ┆ 1.0            │
# │ chr1  ┆ 14434    ┆ 14435    ┆ null            ┆ null           ┆ 11             ┆ 0.727          │
# │ chr1  ┆ 14468    ┆ 14469    ┆ null            ┆ null           ┆ 11             ┆ 0.636          │
# │ chr1  ┆ 14485    ┆ 14486    ┆ null            ┆ null           ┆ 11             ┆ 0.909          │
# │ chr1  ┆ 14520    ┆ 14521    ┆ 10              ┆ 0.9            ┆ 11             ┆ 1.0            │
# │ chr1  ┆ 14552    ┆ 14553    ┆ 10              ┆ 0.7            ┆ 11             ┆ 0.909          │
# │ chr1  ┆ 14588    ┆ 14589    ┆ 10              ┆ 0.9            ┆ 11             ┆ 0.727          │
# │ chr1  ┆ 14652    ┆ 14653    ┆ 10              ┆ 0.8            ┆ 12             ┆ 0.833          │
# │ chr1  ┆ 14672    ┆ 14673    ┆ 10              ┆ 0.5            ┆ 12             ┆ 0.417          │
# │ chr1  ┆ 14709    ┆ 14710    ┆ 10              ┆ 0.9            ┆ 12             ┆ 0.917          │
# │ …     ┆ …        ┆ …        ┆ …               ┆ …              ┆ …              ┆ …              │
# │ chrY  ┆ 56886883 ┆ 56886884 ┆ 31              ┆ 0.258          ┆ null           ┆ null           │
# │ chrY  ┆ 56886893 ┆ 56886894 ┆ 31              ┆ 0.742          ┆ null           ┆ null           │
# │ chrY  ┆ 56886916 ┆ 56886917 ┆ 31              ┆ 0.806          ┆ null           ┆ null           │
# │ chrY  ┆ 56886953 ┆ 56886954 ┆ 31              ┆ 0.419          ┆ null           ┆ null           │
# │ chrY  ┆ 56887024 ┆ 56887025 ┆ 31              ┆ 0.839          ┆ null           ┆ null           │
# │ chrY  ┆ 56887088 ┆ 56887089 ┆ 31              ┆ 0.742          ┆ null           ┆ null           │
# │ chrY  ┆ 56887098 ┆ 56887099 ┆ 31              ┆ 0.839          ┆ null           ┆ null           │
# │ chrY  ┆ 56887220 ┆ 56887221 ┆ 31              ┆ 0.935          ┆ null           ┆ null           │
# │ chrY  ┆ 56887399 ┆ 56887400 ┆ 31              ┆ 0.774          ┆ null           ┆ null           │
# │ chrY  ┆ 56887579 ┆ 56887580 ┆ 31              ┆ 0.903          ┆ null           ┆ null           │
# │ chrY  ┆ 56887592 ┆ 56887593 ┆ 31              ┆ 0.613          ┆ null           ┆ null           │
# │ chrY  ┆ 56887700 ┆ 56887701 ┆ 31              ┆ 0.613          ┆ null           ┆ null           │
# └───────┴──────────┴──────────┴─────────────────┴────────────────┴────────────────┴────────────────┘

# %%
DF_METH_MODEL_HAP1_HAP2
# Out:
# shape: (26_729_958, 7)
# ┌───────┬──────────┬──────────┬─────────────────┬────────────────┬────────────────┬────────────────┐
# │ chrom ┆ start    ┆ end      ┆ total_read_coun ┆ methylation_le ┆ total_read_cou ┆ methylation_le │
# │ ---   ┆ ---      ┆ ---      ┆ t_hap1          ┆ vel_hap1       ┆ nt_hap2        ┆ vel_hap2       │
# │ str   ┆ i64      ┆ i64      ┆ ---             ┆ ---            ┆ ---            ┆ ---            │
# │       ┆          ┆          ┆ i64             ┆ f64            ┆ i64            ┆ f64            │
# ╞═══════╪══════════╪══════════╪═════════════════╪════════════════╪════════════════╪════════════════╡
# │ chr1  ┆ 14061    ┆ 14062    ┆ null            ┆ null           ┆ 10             ┆ 0.211          │
# │ chr1  ┆ 14178    ┆ 14179    ┆ null            ┆ null           ┆ 10             ┆ 0.82           │
# │ chr1  ┆ 14348    ┆ 14349    ┆ null            ┆ null           ┆ 11             ┆ 0.95           │
# │ chr1  ┆ 14353    ┆ 14354    ┆ null            ┆ null           ┆ 11             ┆ 0.958          │
# │ chr1  ┆ 14434    ┆ 14435    ┆ null            ┆ null           ┆ 11             ┆ 0.953          │
# │ chr1  ┆ 14468    ┆ 14469    ┆ null            ┆ null           ┆ 11             ┆ 0.956          │
# │ chr1  ┆ 14485    ┆ 14486    ┆ null            ┆ null           ┆ 11             ┆ 0.963          │
# │ chr1  ┆ 14520    ┆ 14521    ┆ 10              ┆ 0.969          ┆ 11             ┆ 0.966          │
# │ chr1  ┆ 14552    ┆ 14553    ┆ 10              ┆ 0.93           ┆ 11             ┆ 0.952          │
# │ chr1  ┆ 14588    ┆ 14589    ┆ 10              ┆ 0.94           ┆ 11             ┆ 0.931          │
# │ chr1  ┆ 14652    ┆ 14653    ┆ 10              ┆ 0.893          ┆ 12             ┆ 0.937          │
# │ chr1  ┆ 14672    ┆ 14673    ┆ 10              ┆ 0.797          ┆ 12             ┆ 0.686          │
# │ chr1  ┆ 14709    ┆ 14710    ┆ 10              ┆ 0.953          ┆ 12             ┆ 0.963          │
# │ …     ┆ …        ┆ …        ┆ …               ┆ …              ┆ …              ┆ …              │
# │ chrY  ┆ 56886883 ┆ 56886884 ┆ 31              ┆ 0.45           ┆ null           ┆ null           │
# │ chrY  ┆ 56886893 ┆ 56886894 ┆ 31              ┆ 0.834          ┆ null           ┆ null           │
# │ chrY  ┆ 56886916 ┆ 56886917 ┆ 31              ┆ 0.92           ┆ null           ┆ null           │
# │ chrY  ┆ 56886953 ┆ 56886954 ┆ 31              ┆ 0.605          ┆ null           ┆ null           │
# │ chrY  ┆ 56887024 ┆ 56887025 ┆ 31              ┆ 0.949          ┆ null           ┆ null           │
# │ chrY  ┆ 56887088 ┆ 56887089 ┆ 31              ┆ 0.932          ┆ null           ┆ null           │
# │ chrY  ┆ 56887098 ┆ 56887099 ┆ 31              ┆ 0.954          ┆ null           ┆ null           │
# │ chrY  ┆ 56887220 ┆ 56887221 ┆ 31              ┆ 0.962          ┆ null           ┆ null           │
# │ chrY  ┆ 56887399 ┆ 56887400 ┆ 31              ┆ 0.946          ┆ null           ┆ null           │
# │ chrY  ┆ 56887579 ┆ 56887580 ┆ 31              ┆ 0.947          ┆ null           ┆ null           │
# │ chrY  ┆ 56887592 ┆ 56887593 ┆ 31              ┆ 0.725          ┆ null           ┆ null           │
# │ chrY  ┆ 56887700 ┆ 56887701 ┆ 31              ┆ 0.748          ┆ null           ┆ null           │
# └───────┴──────────┴──────────┴─────────────────┴────────────────┴────────────────┴────────────────┘

# %% [markdown]
# ### Phase DNA methylation levels to founder haplotypes

# %%
import phase_meth_to_founder_haps
importlib.reload(phase_meth_to_founder_haps)
from phase_meth_to_founder_haps import phase_meth_to_founder_haps

DF_METH_COUNT_FOUNDER_PHASED = phase_meth_to_founder_haps(DF_METH_COUNT_HAP1_HAP2, DF_HAP_MAP)
DF_METH_MODEL_FOUNDER_PHASED = phase_meth_to_founder_haps(DF_METH_MODEL_HAP1_HAP2, DF_HAP_MAP)

# %%
print(len(DF_METH_COUNT_FOUNDER_PHASED))
DF_METH_COUNT_FOUNDER_PHASED.filter(pl.col("start_hap_map_block").is_not_null()).head()
# Out:
# 26729958
# shape: (5, 13)
# ┌───────┬────────┬────────┬─────────────┬───┬─────────────┬─────────────┬─────────────┬────────────┐
# │ chrom ┆ start  ┆ end    ┆ start_hap_m ┆ … ┆ total_read_ ┆ total_read_ ┆ founder_hap ┆ founder_ha │
# │ ---   ┆ ---    ┆ ---    ┆ ap_block    ┆   ┆ count_pat   ┆ count_mat   ┆ lotype_pat  ┆ plotype_ma │
# │ str   ┆ i64    ┆ i64    ┆ ---         ┆   ┆ ---         ┆ ---         ┆ ---         ┆ t          │
# │       ┆        ┆        ┆ i64         ┆   ┆ f64         ┆ f64         ┆ str         ┆ ---        │
# │       ┆        ┆        ┆             ┆   ┆             ┆             ┆             ┆ str        │
# ╞═══════╪════════╪════════╪═════════════╪═══╪═════════════╪═════════════╪═════════════╪════════════╡
# │ chr1  ┆ 496845 ┆ 496846 ┆ 492339      ┆ … ┆ null        ┆ 10.0        ┆ B           ┆ I          │
# │ chr1  ┆ 496861 ┆ 496862 ┆ 492339      ┆ … ┆ null        ┆ 10.0        ┆ B           ┆ I          │
# │ chr1  ┆ 497014 ┆ 497015 ┆ 492339      ┆ … ┆ null        ┆ 11.0        ┆ B           ┆ I          │
# │ chr1  ┆ 497036 ┆ 497037 ┆ 492339      ┆ … ┆ null        ┆ 11.0        ┆ B           ┆ I          │
# │ chr1  ┆ 497039 ┆ 497040 ┆ 492339      ┆ … ┆ null        ┆ 11.0        ┆ B           ┆ I          │
# └───────┴────────┴────────┴─────────────┴───┴─────────────┴─────────────┴─────────────┴────────────┘

# %%
print(len(DF_METH_MODEL_FOUNDER_PHASED))
DF_METH_MODEL_FOUNDER_PHASED.filter(pl.col("start_hap_map_block").is_not_null()).head()
# Out:
# 26729958
# shape: (5, 13)
# ┌───────┬────────┬────────┬─────────────┬───┬─────────────┬─────────────┬─────────────┬────────────┐
# │ chrom ┆ start  ┆ end    ┆ start_hap_m ┆ … ┆ total_read_ ┆ total_read_ ┆ founder_hap ┆ founder_ha │
# │ ---   ┆ ---    ┆ ---    ┆ ap_block    ┆   ┆ count_pat   ┆ count_mat   ┆ lotype_pat  ┆ plotype_ma │
# │ str   ┆ i64    ┆ i64    ┆ ---         ┆   ┆ ---         ┆ ---         ┆ ---         ┆ t          │
# │       ┆        ┆        ┆ i64         ┆   ┆ f64         ┆ f64         ┆ str         ┆ ---        │
# │       ┆        ┆        ┆             ┆   ┆             ┆             ┆             ┆ str        │
# ╞═══════╪════════╪════════╪═════════════╪═══╪═════════════╪═════════════╪═════════════╪════════════╡
# │ chr1  ┆ 496845 ┆ 496846 ┆ 492339      ┆ … ┆ null        ┆ 10.0        ┆ B           ┆ I          │
# │ chr1  ┆ 496861 ┆ 496862 ┆ 492339      ┆ … ┆ null        ┆ 10.0        ┆ B           ┆ I          │
# │ chr1  ┆ 497014 ┆ 497015 ┆ 492339      ┆ … ┆ null        ┆ 11.0        ┆ B           ┆ I          │
# │ chr1  ┆ 497036 ┆ 497037 ┆ 492339      ┆ … ┆ null        ┆ 11.0        ┆ B           ┆ I          │
# │ chr1  ┆ 497039 ┆ 497040 ┆ 492339      ┆ … ┆ null        ┆ 11.0        ┆ B           ┆ I          │
# └───────┴────────┴────────┴─────────────┴───┴─────────────┴─────────────┴─────────────┴────────────┘

# %% [markdown]
# ### Combine count-based and model-based methylation levels

# %%
import phase_meth_to_founder_haps
importlib.reload(phase_meth_to_founder_haps)
from phase_meth_to_founder_haps import combine_count_and_model_based_methylation_levels

DF_METH_FOUNDER_PHASED = combine_count_and_model_based_methylation_levels(DF_METH_COUNT_FOUNDER_PHASED, DF_METH_MODEL_FOUNDER_PHASED)
DF_METH_FOUNDER_PHASED
# Out:
# shape: (26_729_958, 15)
# ┌───────┬──────────┬──────────┬────────────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ chrom ┆ start    ┆ end      ┆ start_hap_ ┆ … ┆ methylatio ┆ methylatio ┆ methylatio ┆ methylatio │
# │ ---   ┆ ---      ┆ ---      ┆ map_block  ┆   ┆ n_level_pa ┆ n_level_ma ┆ n_level_pa ┆ n_level_ma │
# │ str   ┆ i64      ┆ i64      ┆ ---        ┆   ┆ t_count    ┆ t_count    ┆ t_model    ┆ t_model    │
# │       ┆          ┆          ┆ i64        ┆   ┆ ---        ┆ ---        ┆ ---        ┆ ---        │
# │       ┆          ┆          ┆            ┆   ┆ f64        ┆ f64        ┆ f64        ┆ f64        │
# ╞═══════╪══════════╪══════════╪════════════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ chr1  ┆ 14061    ┆ 14062    ┆ null       ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ chr1  ┆ 14178    ┆ 14179    ┆ null       ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ chr1  ┆ 14348    ┆ 14349    ┆ null       ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ chr1  ┆ 14353    ┆ 14354    ┆ null       ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ chr1  ┆ 14434    ┆ 14435    ┆ null       ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ chr1  ┆ 14468    ┆ 14469    ┆ null       ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ chr1  ┆ 14485    ┆ 14486    ┆ null       ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ chr1  ┆ 14520    ┆ 14521    ┆ null       ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ chr1  ┆ 14552    ┆ 14553    ┆ null       ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ chr1  ┆ 14588    ┆ 14589    ┆ null       ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ chr1  ┆ 14652    ┆ 14653    ┆ null       ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ chr1  ┆ 14672    ┆ 14673    ┆ null       ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ chr1  ┆ 14709    ┆ 14710    ┆ null       ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ …     ┆ …        ┆ …        ┆ …          ┆ … ┆ …          ┆ …          ┆ …          ┆ …          │
# │ chrY  ┆ 56886883 ┆ 56886884 ┆ null       ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ chrY  ┆ 56886893 ┆ 56886894 ┆ null       ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ chrY  ┆ 56886916 ┆ 56886917 ┆ null       ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ chrY  ┆ 56886953 ┆ 56886954 ┆ null       ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ chrY  ┆ 56887024 ┆ 56887025 ┆ null       ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ chrY  ┆ 56887088 ┆ 56887089 ┆ null       ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ chrY  ┆ 56887098 ┆ 56887099 ┆ null       ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ chrY  ┆ 56887220 ┆ 56887221 ┆ null       ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ chrY  ┆ 56887399 ┆ 56887400 ┆ null       ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ chrY  ┆ 56887579 ┆ 56887580 ┆ null       ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ chrY  ┆ 56887592 ┆ 56887593 ┆ null       ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ chrY  ┆ 56887700 ┆ 56887701 ┆ null       ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# └───────┴──────────┴──────────┴────────────┴───┴────────────┴────────────┴────────────┴────────────┘

# %% [markdown]
# ### Notes

# %% [markdown]
# #### Why some SNPs can be read-phased, but not pedigree-phased
#
# https://quinlangroup.slack.com/archives/C09027S4C5Q/p1750792033498849
